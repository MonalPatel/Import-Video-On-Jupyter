# %% [markdown]
# # Display youtube video in jupyter notebook

# %% [markdown]
# If you want to display the youtube video in Jupyter notebook
# type below code to import youtube video;

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('b_pTxGu2L04')

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('xPPgGHoCoCA')
